# %% [markdown]
# ## Simple genai app with LangChain and OpenAI

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["LANGCHAIN_API_KEY"]= os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]= "true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
## data ingestion from a website
from langchain_community.document_loaders import WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader("https://www.langchain.com/")
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content="LangChain: Observe, Evaluate, and Deploy Reliable AI Agents\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nProducts\n\nLangSmithObservabilityDebug and monitor in-depth tracesEvaluationIterate on prompts and modelsDeploymentShip and scale agents in productionAgent BuilderNewBuild no-code agentsOpen Source FrameworksLangChainQuick start agents with any model providerLangGraphBuild custom agents with low-level controlDeep AgentsNewUse planning, memory, and sub-agents for complex, long-running tasksLearn\n\nResourcesBlog2026 State of Agent EngineeringCustomer StoriesGuidesChangelogTrust CenterSupportHow-ToLangChain AcademyYouTubeDocumentationCommunityEventsCommunityCommunity ForumSlackDocsCompany\n\nAboutCareersPartnersPricingGet a demoTry LangSmithShip reliable agentsObserve, evaluate, and deploy agents with LangSmith,the agent engineering platform.\n\n\n\n\nGet started withLangSmith for freeOur free plan includes:5,000 free traces per monthTracing to debug agent execution Online and offline evalsMonitoring and alertingTry LangSmithLangSmith powers top engineering teams, from AI startups to global enterprisesVisibility &\xa0controlSee exactly what's happening at every step of your agent. Steer your agent to accomplish critical tasks the way you intended.Fast iterationRapidly move through build, test, deploy, learn, repeat with workflows across the entire agent engineering lifecycle.Durable performanceShip at scale with agent infrastructure designed for long-running workloads and human oversight.Framework neutralKeep your current stack. LangSmith works with your preferred open-source framework or custom code.LangSmith Agent Engineering PlatformImprove agent performance across the development lifecycle. Bring your preferred framework or custom code – LangSmith works with any agent stack using our TypeScript and Python SDKs.\n\n\nObservabilitySee exactly what your agent is doingAgents create dense outputs that make debugging hard. Tracing gives you clear visibility into each step, so you can quickly identify issues and confidently explain what your agent is actually doing.LangSmith Observability\n\n\n\n\n\n\n\nEvaluationDebug traces and monitor trendsEvaluating agents isn’t as simple as writing tests and shipping. Turn live data into test datasets, then score performace with automated evaluators and expert feedback. Iterate to continuously improve quality as you learn what “good” looks like throught real-world usage.LangSmith Evaluation\n\n\n\n\n\n\nDeploymentShip and scale agents in productionStandard infrastructure can’t handle long-running agent workloads that need human collaboration. Deploy in one click with APIs that handle memory, auto-scaling, and enterprise-grade security out of the box — built for agent workflows that run for hours or days.LangSmith Deployment\n\n\n\n\nAgent BuilderNo-code agents for real workMultiply your capacity with AI agents built around your\xa0routines.LangSmith Agent Builder\n\n\n\nOpen Source FrameworksBuild and ship agents fast with any model provider. Use high-level abstractions or fine-grained control as needed.LangChainQuick start agents with any model providerLangChain\n\n\nLangGraphBuild custom agents with low-level controlLangGraph\n\n\nDeep AgentsUse planning, memory, and sub-agents for complex, long-running tasksDeep Agents\n\n\nExplore top agent use casesEnterprise GPTGive all employees access to information and tools in a compliant manner so they can perform their best.Customer SupportImprove the speed and efficiency of support teams that handle customer requests.ResearchSynthesize data, summarize sources, and uncover insights faster for knowledge work.CopilotsBuild native co- ...

# %%
## load Data --> Docs --> divide text in to chunks --> create vector store --> retriever --> question answering


from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(docs)
documents
# Out:
# [Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content='LangChain: Observe, Evaluate, and Deploy Reliable AI Agents\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nProducts\n\nLangSmithObservabilityDebug and monitor in-depth tracesEvaluationIterate on prompts and modelsDeploymentShip and scale agents in productionAgent BuilderNewBuild no-code agentsOpen Source FrameworksLangChainQuick start agents with any model providerLangGraphBuild custom agents with low-level controlDeep AgentsNewUse planning, memory, and sub-agents for complex, long-running tasksLearn\n\nResourcesBlog2026 State of Agent EngineeringCustomer StoriesGuidesChangelogTrust CenterSupportHow-ToLangChain AcademyYouTubeDocumentationCommunityEventsCommunityCommunity ForumSlackDocsCompany\n\nAboutCareersPartnersPricingGet a demoTry LangSmithShip reliable agentsObserve, evaluate, and deploy agents with LangSmith,the agent engineering platform.'),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content="Get started withLangSmith for freeOur free plan includes:5,000 free traces per monthTracing to debug agent execution Online and offline evalsMonitoring and alertingTry LangSmithLangSmith powers top engineering teams, from AI startups to global enterprisesVisibility &\xa0controlSee exactly what's happening at every step of your agent. Steer your agent to accomplish critical tasks the way you intended.Fast iterationRapidly move through build, test, deploy, learn, repeat with workflows across the entire agent engineering lifecycle.Durable performanceShip at scale with agent infrastructure designed for long-running workloads and human oversight.Framework neutralKeep your current stack. LangSmith works with your preferred open-source framework or custom code.LangSmith Agent Engineering PlatformImprove agent performance across the development lifecycle. Bring your preferred framework or custom code – LangSmith works with any agent stack using our TypeScript and Python SDKs."),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content='ObservabilitySee exactly what your agent is doingAgents create dense outputs that make debugging hard. Tracing gives you clear visibility into each step, so you can quickly identify issues and confidently explain what your agent is actually doing.LangSmith Observability\n\n\n\n\n\n\n\nEvaluationDebug traces and monitor trendsEvaluating agents isn’t as simple as writing tests and shipping. Turn live data into test datasets, then score performace with automated evaluators and expert feedback. Iterate to continuously improve quality as you learn what “good” looks like throught real-world usage.LangSmith Evaluation\n\n\n\n\n\n\nDeploymentShip and scale agents in productionStandard infrastructure can’t handle long-running agent workloads that need human collaboration. Deploy in one click with APIs that handle memory, auto-scaling, and enterprise-grade security out of the box — built for agent workflows that run for hours or days.LangSmith Deployment'),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content='Agent BuilderNo-code agents for real workMultiply your capacity with AI agents built around your\xa0routines.LangSmith Agent Builder\n\n\n\nOpen Source FrameworksBuild and ship agents fast with any model provider. Use high-level abstractions or fine-grained control as needed.LangChainQuick start agents with any model providerLangChain\n\n\nLangGraphBuild custom agents with low-level controlLangGraph\n\n\nDeep AgentsUse planning, memory, and sub-agents for complex, long-running tasksDeep Agents'),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content='LangGraphBuild custom agents with low-level controlLangGraph\n\n\nDeep AgentsUse planning, memory, and sub-agents for complex, long-running tasksDeep Agents\n\n\nExplore top agent use casesEnterprise GPTGive all employees access to information and tools in a compliant manner so they can perform their best.Customer SupportImprove the speed and efficiency of support teams that handle customer requests.ResearchSynthesize data, summarize sources, and uncover insights faster for knowledge work.CopilotsBuild native co-pilots into your application to unlock new end user experiences for domain-specific tasks.AI SearchOffer a concierge experience to guide users to products or information in a personalized way.\n\n\n\n\n\nGet inspired by companies who have done itTeams building with LangChain products are driving operational efficiency, increasing discovery & personalization, and delivering premium products that generate revenue.Read their stories'),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content="Financial ServicesKlarna's AI assistant reduced customer query resolution time by 80%, powered by LangSmith and LangGraph.\n\n\nB2B SaaSElastic’s AI security assistant, built with LangSmith and LangGraph, cut alert response times for 20,000+ customers.\n\n\nAI/MLRakuten’s GenAI platform, built with LangGraph and LangSmith, lets employees across 70+ businesses create AI agents.\n\n\nLearn alongside the 1 million+ practitioners who are pushing the industry forward90MMonthly downloads100k+GitHub stars#1Downloaded agent framework1000IntegrationsConceptual GuidesExplore our guides and resources to understand key concepts relating to AI agents.\n\n\n\n\n\nAgent observability powers agent evaluation\n\n\nThe Definitive Guide to Testing LLM ApplicationsDownload now\n\n\nHow we built Agent Builder’s memory system"),
#  Document(metadata={'source': 'https://www.langchain.com/', 'title': 'LangChain: Observe, Evaluate, and Deploy Reliable AI Agents', 'description': 'LangChain provides the engineering platform and open source frameworks developers use to build, test, and deploy reliable AI agents.', 'language': 'en'}, page_content='Agent observability powers agent evaluation\n\n\nThe Definitive Guide to Testing LLM ApplicationsDownload now\n\n\nHow we built Agent Builder’s memory system\n\n\nReady to start shipping \u2028reliable agents faster?Get started with tools from the LangChain product suite for every step of the agent development lifecycle.Get a demoTry LangSmithProductsLangChainLangGraphLangSmith ObservabilityLangSmith EvaluationLangSmith DeploymentResourcesGuidesBlogCustomer StoriesLangChain AcademyCommunityEventsChangelogDocsSupportCompanyAboutCareersXLinkedInYouTubeMarketing AssetsSecuritySign up for our newsletter to stay up to dateThank you! Your submission has been received!Oops! Something went wrong while submitting the form.All systems operationalPrivacy PolicyTerms of Service')]

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# %%
from langchain_community.vectorstores import FAISS
vectorstoredb = FAISS.from_documents(documents, embeddings)
vectorstoredb.save_local("faiss_index")

# %%
vectorstoredb
