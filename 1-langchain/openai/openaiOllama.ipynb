# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["LANGCHAIN_API_KEY"]= os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]= "true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.7
)
print(llm)
# Out:
# profile={} client=<openai.resources.chat.completions.completions.Completions object at 0x000001B65F3A64E0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001B660CB26F0> root_client=<openai.OpenAI object at 0x000001B65F62F6B0> root_async_client=<openai.AsyncOpenAI object at 0x000001B6608DD850> model_name='openai/gpt-4o-mini' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## input and get response from the llm
result = llm.invoke("What is the capital of France?")

# %%
result
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 14, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'cost': 6.3e-06, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 6.3e-06, 'upstream_inference_prompt_cost': 2.1e-06, 'upstream_inference_completions_cost': 4.2e-06}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_1590f93f9d', 'id': 'gen-1769951283-iQIjHtTceIVomeDwlKMf', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c1951-49fe-7730-bfc5-a6db3a47f2ec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 7, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### chatprompt template

from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "you are an expert ai engineer . Provide me answers based on the questions"),
    ("human", "{input}")
])   
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an expert ai engineer . Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm

# %%
response = chain.invoke({"input": "What is the capital of Germany?"})

# %%
response
# Out:
# AIMessage(content='The capital of Germany is Berlin.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 32, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'cost': 9e-06, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 9e-06, 'upstream_inference_prompt_cost': 4.8e-06, 'upstream_inference_completions_cost': 4.2e-06}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_1590f93f9d', 'id': 'gen-1769951920-O1GVPOYy8VFxdphnl6oY', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c195a-ffee-7cf0-9bac-5ce513b561bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 7, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## string output parser 

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke({"input": "can you tell me about india "})
print(response)
# Out:
# India is a country located in South Asia, known for its rich history, diverse culture, and significant influence on global affairs. Here are some key aspects of India:
#
# 1. **Geography**: India is the seventh-largest country in the world by land area and is bordered by Pakistan, China, Nepal, Bhutan, Bangladesh, and Myanmar. It has a varied landscape that includes the Himalayan mountain range, vast plains, deserts, and coastlines along the Indian Ocean, Arabian Sea, and Bay of Bengal.
#
# 2. **Population**: With over 1.4 billion people, India is the second-most populous country in the world. It is home to a wide range of ethnic groups, languages, and religions, making it one of the most culturally diverse nations.
#
# 3. **History**: India has a complex history that dates back thousands of years. It is known for ancient civilizations such as the Indus Valley Civilization and has been influenced by various empires, including the Maurya and Gupta Empires, the Mughal Empire, and British colonial rule. India gained independence from British rule on August 15, 1947.
#
# 4. **Government**: India is a federal parliamentary democratic republic. It has a multi-tiered system of government, with power divided between the central government and various state governments. The President is the head of state, while the Prime Minister is the head of government.
#
# 5. **Economy**: India has one of the world's largest economies, characterized by a mix of agriculture, manufacturing, and services. It is known for its IT and software services industry, as well as traditional sectors like textiles and agriculture. The country has been experiencing rapid economic growth and development in recent years.
#
# 6. **Culture**: Indian culture is incredibly diverse, with various languages, religions, festivals, and traditions. Major religions originating in India include Hinduism, Buddhism, Jainism, and Sikhism. The country is also home to a large Muslim population, along with Christians, Sikhs, Buddhists, and others.
#
# 7. **Cuisine**: Indian cuisine is famous for its variety and use of spices. Each region has its own specialties, influenced by local ingredients and cultural practices. Popular dishes include curry, biryani, dosa, and various types of bread like naan and roti.
#
# 8. **Tourism**: India is a popular tourist destination, known for its historical landmarks, natural beauty, and cultural experiences. Notable attractions include the Taj Mahal, Jaipur's palaces, Kerala's backwaters, and the spiritual cities of Varanasi and Rishikesh.
#
# 9. **Education and Science**: India has made significant advances in education and scientific research, producing a large number of engineers, doctors, and professionals. The country is also known for its space program, which has achieved notable successes, including missions to the Moon and Mars.
#
# 10. **Challenges**: India faces several challenges, including poverty, inequality, corruption, and environmental issues. The government and various organizations are working to address these challenges through various initiatives and reforms.
#
# Overall, India is a vibrant and dynamic country with a unique blend of tradition and modernity, playing a crucial role on the world stage.
