# %% [markdown]
# Text Splitting from documents

# %%
# read a pdf file 
from langchain_community.document_loaders import PyPDFLoader
pdf_loader = PyPDFLoader(r'D:\generative_Ai\1-langchain\final-resume.pdf')
docs = pdf_loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Piyush_resume', 'source': 'D:\\generative_Ai\\1-langchain\\final-resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='PIYUSH                                                            +91  9717704058  |  piyushrathorecodes@gmail.com  |Portfolio | Linkedin | Github                           Education   Maharaja  Agrasen  Institute  Of  Technology  (New  Delhi)   Bachelor  Of  Technology  in  Computer  Science  with  specialization  in  AIML  |  Graduation  Year  :  2028    ___________________________________________________________________________________________________  Technical  Skills   ●  Programming  Languages:  Python,  C++,  Java  ( Data  Structures  &  Algorithms ),  JavaScript,  C,  SQL  (MySQL,  PostgreSQL)  ●  Web  Development  &  Backend:  HTML5,  CSS3,  React.js,  Node.js,  Express.js,  Django  ●  Databases  &  BaaS:  MongoDB,  M
# ...

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# # how to recusiveely split text by character

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_documents=text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Piyush_resume', 'source': 'D:\\generative_Ai\\1-langchain\\final-resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='PIYUSH                                                            +91  9717704058  |  piyushrathorecodes@gmail.com  |Portfolio | Linkedin | Github                           Education   Maharaja  Agrasen  Institute  Of  Technology  (New  Delhi)   Bachelor  Of  Technology  in  Computer  Science  with  specialization  in  AIML  |  Graduation  Year  :  2028    ___________________________________________________________________________________________________  Technical  Skills   ●  Programming'),
# ...

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='PIYUSH                                                            +91  9717704058  |  piyushrathorecodes@gmail.com  |Portfolio | Linkedin | Github                           Education   Maharaja  Agrasen  Institute  Of  Technology  (New  Delhi)   Bachelor  Of  Technology  in  Computer  Science  with  specialization  in  AIML  |  Graduation  Year  :  2028    ___________________________________________________________________________________________________  Technical  Skills   ●  Programming' metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Piyush_resume', 'source': 'D:\\generative_Ai\\1-langchain\\final-resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
# ...

# %%
# text loader 

from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt', encoding='utf8')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='“The Power of Curiosity”\n\nGood [morning/afternoon/evening] everyone,\n\nHave you ever wondered why we keep asking questions, even when answers seem just out of reach? Curiosity is not just a spark in our minds—it’s the engine of progress. Every great invention, every bold idea, every story of triumph started with a simple question: “What if…?”\n\nCuriosity pushes us beyond comfort, beyond routine, and into discovery. It encourages us to fail, to stumble, and then to rise stronger. It reminds us that knowledge is not a destination, but a journey.\n\nSo today, I urge each of you: embrace your curiosity. Ask questions that scare you. Explore paths no one has walked before. Because in the act of seeking, in the courage to wonder, we find our greatest potential.\n\nRemember, the world doesn’t change because we play it safe—it changes because we dared to ask, dared to learn, and dared to act.\n\nThank you.')]

# %%
with open('speech.txt', 'r', encoding='utf8') as file:
    content = file.read()
    print(content)
# Out:
# “The Power of Curiosity”
#
# Good [morning/afternoon/evening] everyone,
#
# Have you ever wondered why we keep asking questions, even when answers seem just out of reach? Curiosity is not just a spark in our minds—it’s the engine of progress. Every great invention, every bold idea, every story of triumph started with a simple question: “What if…?”
#
# Curiosity pushes us beyond comfort, beyond routine, and into discovery. It encourages us to fail, to stumble, and then to rise stronger. It reminds us that knowledge is not a destination, but a journey.
#
# So today, I urge each of you: embrace your curiosity. Ask questions that scare you. Explore paths no one has walked before. Because in the act of seeking, in the courage to wonder, we find our greatest potential.
#
# Remember, the world doesn’t change because we play it safe—it changes because we dared to ask, dared to learn, and dared to act.
#
# Thank you.

# %%
speech = ""

with open ("speech.txt", encoding='utf8') as f:
      speech = f.read()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text = text_splitter.create_documents([speech])
print(text[0])
# Out:
# page_content='“The Power of Curiosity”
#
# Good [morning/afternoon/evening] everyone,'
